# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# from google.colab import drive
# from google.colab.patches import cv2_imshow

# %%
# drive.mount('/content/drive')

# %%
img = cv2.imread('../images/girl.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gImg.shape)
plt.imshow(gImg, cmap='gray')

# cv2.imshow('Lena', RGB_img)
# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# (256, 256)

# %%
gPlus =  np.zeros((gImg.shape[0], gImg.shape[1]), dtype=np.ubyte)

# %%
val = 100
gImg = gImg.astype(int)
for h in range(gImg.shape[0]):
    for w in range(gImg.shape[1]):
        plusVal = np.int32(gImg[h, w] + val)
        if(plusVal > 255):
            plusVal = 255
        gPlus[h, w] = plusVal

plt.imshow(gPlus, cmap='gray')

# %%
img = cv2.imread('../images/aero2.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gImg1.shape)
plt.imshow(gImg1, cmap='gray')
#cv2.imshow('Lena', gImg1)
# Out:
# (256, 256)

# %%
img = cv2.imread('../images/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gImg2.shape)
plt.imshow(gImg2, cmap='gray')
#cv2.imshow('Lena', gImg2)
# Out:
# (256, 256)

# %%
gPlus =  np.zeros((gImg.shape[0], gImg.shape[1]), dtype=np.ubyte)

# %%
for h in range(gImg1.shape[0]):
    for w in range(gImg1.shape[1]):
        plusVal = np.int32(gImg1[h, w]) + np.int32(gImg2[h, w])
        if plusVal > 255:
            plusVal = 255
        gPlus[h, w] = plusVal
plt.imshow(gPlus, cmap='gray')
#cv2.imshow('Lena', gPlus)

# %%
# 2개의 영상을 더하는 코드
weight = 0.5

for h in range(gImg1.shape[0]):
    for w in range(gImg1.shape[1]):
        plusVal = np.int32(gImg1[h, w])*weight + np.int32(gImg2[h, w])*(1-weight)
        if(plusVal > 255):
            plusVal = 255
        gPlus[h, w] = plusVal

plt.imshow(gPlus, cmap='gray')
#cv2.imshow('Lena', gPlus)
